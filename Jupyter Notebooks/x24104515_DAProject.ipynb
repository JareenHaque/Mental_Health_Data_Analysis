# %% [markdown]
# ## **Libraries**

# %%
import json
import pandas as pd
import pymongo
from pymongo import MongoClient
import numpy as np

 # JSON for read json file
 # Pandas for data manipulation

# %% [markdown]
# ## **Importing JSON file**

# %%
filepath = "C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicatorsad.json"

def import_json(filepath):
    try:
        with open (filepath, "r") as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        print(f"The file {filepath} was not found")
    except PermissionError:
        print(f"Insufficient permission to read the file {filepath}")
    except json.JSONDecodeError as jde:
        print(f"JSONDecodeError: {jde}")
        print("Please ensure the file contains valid JSON.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    return {}

# %% [markdown]
# ## **Loading data**

# %%
data = import_json(filepath) # Reading JSON file

indicators = data
indicators
# Out:
# {'meta': {'view': {'id': '8pt5-q6wp',
#    'name': 'Indicators of Anxiety or Depression Based on Reported Frequency of Symptoms During Last 7 Days',
#    'assetType': 'dataset',
#    'attribution': 'NCHS/DHIS',
#    'averageRating': 0,
#    'category': 'NCHS',
#    'createdAt': 1589990736,
#    'description': 'The U.S. Census Bureau, in collaboration with five federal agencies, launched the Household Pulse Survey to produce data on the social and economic impacts of Covid-19 on American households.  The Household Pulse Survey was designed to gauge the impact of the pandemic on employment status, consumer spending, food security, housing, education disruptions, and dimensions of physical and mental wellness.\n\nThe survey was designed to meet the goal of accurate and timely weekly estimates. It was conducted by an internet questionnaire, with invitations to participate sent by email and text message. The sample frame is the Census Bureau Master Address File Data. Housing units linked to one or more email addresses or cell phone numbers were randomly selected to participate, and one respondent from each housing unit was selected to respond for him or herself. Estimates are weighted to adjust for nonresponse and to match Census Bureau estimates of the population by age, gender, race and ethnicity, and educational attainment. All estimates shown meet the NCHS Data Presentation Standards for Proportions,',
#    'displayType': 'table',
#    'downloadCount': 64177,
#    'hideFromCatalog': False,
#    'hideFromDataJson': False,
#    'licenseId': 'USGOV_WORKS',
#    'locked': False,
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 38411991,
#    'provenance': 'official',
#    'publicationAppendEnabled': False,
#    'publicationDate': 1650465349,
#    'publicationGroup': 17141804,
#    'publicationStage': 'published',
#    'rowsUpdatedAt': 1728050798,
#    'rowsUpdatedBy': 'xfvr-ns68',
#    'tableId': 18676685,
#    'totalTimesRated': 0,
#    'viewCount': 58757,
#    'viewLastModified': 1728050794,
#    'viewType': 'tabular',
#    'approvals': [{'reviewedAt': 1590009957,
#      'reviewedAutomatically': True,
#      'state': 'approved',
#      'submissionId': 4635361,
#      'submissionObject': 'public_audience_request',
#      'submissionOutcome': 'change_audience',
#      'submittedAt': 1590009957,
#      'targetAudience': 'public',
#      'workflowId': 2100,
#      'submissionDetails': {'permissionType': 'READ'},
#      'submissionOutcomeApplication': {'endedAt': 1590009958,
#       'failureCount': 0,
#       'startedAt': 1590009957,
#       'status': 'success'},
#      'submitter': {'id': 'ki96-txhe', 'displayName': 'NCHS'}}],
#    'clientContext': {'clientContextVariables': [], 'inheritedVariables': {}},
#    'columns': [{'id': -1,
#      'name': 'sid',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':sid',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'id',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':id',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'position',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':position',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': 559238944,
#      'name': 'Indicator',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'indicator',
#      'position': 1,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255558,
#      'cachedContents': {'non_null': '16794',
#       'largest': 'Symptoms of Depressive Disorder',
#       'null': '0',
#       'top': [{'item': 'Symptoms of Anxiety Disorder or Depressive Disorder',
#         'count': '5598'},
#        {'item': 'Symptoms of Anxiety Disorder', 'count': '5598'},
#        {'item': 'Symptoms of Depressive Disorder', 'count': '5598'}],
#       'smallest': 'Symptoms of Anxiety Disorder',
#       'count': '16794',
#       'cardinality': '3'},
#      'format': {}},
#     {'id': 559238945,
#      'name': 'Group',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'group',
#      'position': 2,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255559,
#      'cachedContents': {'non_null': '16794',
#       'largest': 'National Estimate',
#       'null': '0',
#       'top': [{'item': 'By State', 'count': '11016'},
#        {'item': 'By Age', 'count': '1722'},
#        {'item': 'By Race/Hispanic ethnicity', 'count': '1230'},
#        {'item': 'By Education', 'count': '984'},
#        {'item': 'By Sex', 'count': '492'},
#        {'item': 'By Sexual orientation', 'count': '396'},
#        {'item': 'By Gender identity', 'count': '396'},
#        {'item': 'By Disability status', 'count': '312'},
#        {'item': 'National Estimate', 'count': '246'}],
#       'smallest': 'By Age',
#       'count': '16794',
#       'cardinality': '9'},
#      'format': {}},
#     {'id': 559238946,
#      'name': 'State',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'state',
#      'position': 3,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255560,
#      'cachedContents': {'non_null': '16794',
#       'largest': 'Wyoming',
#       'null': '0',
#       'top': [{'item': 'United States', 'count': '5778'},
#        {'item': 'Texas', 'count': '216'},
#        {'item': 'Oregon', 'count': '216'},
#        {'item': 'Idaho', 'count': '216'},
#        {'item': 'Alaska', 'count': '216'},
#        {'item': 'Alabama', 'count': '216'},
#        {'item': 'Oklahoma', 'count': '216'},
#        {'item': 'North Carolina', 'count': '216'},
#        {'item': 'Colorado', 'count': '216'},
#        {'item': 'Mississippi', 'count': '216'},
#        {'item': 'Florida', 'count': '216'},
#        {'item': 'Vermont', 'count': '216'},
#        {'item': 'Delaware', 'count': '216'},
#        {'item': 'Nevada', 'count': '216'},
#        {'item': 'Louisiana', 'count': '216'},
#        {'item': 'New York', 'count': '216'},
#        {'item': 'West Virginia', 'count': '216'},
#        {'item': 'South Carolina', 'count': '216'},
#        {'item': 'New Jersey', 'count': '216'},
#        {'item': 'New Mexico', 'count': '216'}],
#       'smallest': 'Alabama',
#       'count': '16794',
#       'cardinality': '52'},
#      'format': {}},
#     {'id': 559238947,
#      'name': 'Subgroup',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'subgroup',
#      'position': 4,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255561,
#      'cachedContents': {'non_null': '16794',
#       'largest': 'Wyoming',
#       'null': '0',
#       'top': [{'item': "Bachelor's degree or higher", 'count': '246'},
#        {'item': 'Female', 'count': '246'},
#        {'item': '80 years and above', 'count': '246'},
#        {'item': 'Non-Hispanic Asian, single race', 'count': '246'},
#        {'item': 'Less than a high school diploma', 'count': '246'},
#        {'item': "Some college/Associate's degree", 'count': '246'},
#        {'item': 'High school diploma or GED', 'count': '246'},
#        {'item': 'Male', 'count': '246'},
#        {'item': '60 - 69 years', 'count': '246'},
#        {'item': '70 - 79 years', 'count': '246'},
#        {'item': 'United States', 'count': '246'},
#        {'item': '40 - 49 years', 'count': '246'},
#        {'item': 'Non-Hispanic, other races and multiple races',
#         'count': '246'},
#        {'item': 'Non-Hispanic White, single race', 'count': '246'},
#        {'item': 'Hispanic or Latino', 'count': '246'},
#        {'item': '50 - 59 years', 'count': '246'},
#        {'item': '18 - 29 years', 'count': '246'},
#        {'item': 'Non-Hispanic Black, single race', 'count': '246'},
#        {'item': '30 - 39 years', 'count': '246'},
#        {'item': 'Wyoming', 'count': '216'}],
#       'smallest': '18 - 29 years',
#       'count': '16794',
#       'cardinality': '78'},
#      'format': {}},
#     {'id': 559238948,
#      'name': 'Phase',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'phase',
#      'position': 5,
#      'renderTypeName': 'text',
#      'tableColumnId': 130119080,
#      'cachedContents': {'non_null': '16794',
#       'largest': '4.2',
#       'null': '0',
#       'top': [{'item': '1', 'count': '2520'},
#        {'item': '3.1', 'count': '1998'},
#        {'item': '3.2', 'count': '1404'},
#        {'item': '3.0 (Jan 6 - Mar 29)', 'count': '1260'},
#        {'item': '2', 'count': '1050'},
#        {'item': '4.1', 'count': '936'},
#        {'item': '3.0 (Oct 28 - Dec 21)', 'count': '840'},
#        {'item': '3.5', 'count': '702'},
#        {'item': '-1', 'count': '702'},
#        {'item': '3.4', 'count': '702'},
#        {'item': '3.8', 'count': '702'},
#        {'item': '3.9', 'count': '702'},
#        {'item': '3.7', 'count': '702'},
#        {'item': '3.3', 'count': '702'},
#        {'item': '3.6', 'count': '702'},
#        {'item': '4', 'count': '702'},
#        {'item': '4.2', 'count': '468'}],
#       'smallest': '1',
#       'count': '16794',
#       'cardinality': '17'},
#      'format': {}},
#     {'id': 559238949,
#      'name': 'Time Period',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'time_period',
#      'position': 6,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255555,
#      'cachedContents': {'non_null': '16794',
#       'largest': '9',
#       'null': '0',
#       'top': [{'item': '1', 'count': '912'},
#        {'item': '37', 'count': '234'},
#        {'item': '40', 'count': '234'},
#        {'item': '65', 'count': '234'},
#        {'item': '44', 'count': '234'},
#        {'item': '59', 'count': '234'},
#        {'item': '55', 'count': '234'},
#        {'item': '54', 'count': '234'},
#        {'item': '64', 'count': '234'},
#        {'item': '68', 'count': '234'},
#        {'item': '47', 'count': '234'},
#        {'item': '58', 'count': '234'},
#        {'item': '52', 'count': '234'},
#        {'item': '57', 'count': '234'},
#        {'item': '34', 'count': '234'},
#        {'item': '39', 'count': '234'},
#        {'item': '56', 'count': '234'},
#        {'item': '48', 'count': '234'},
#        {'item': '35', 'count': '234'},
#        {'item': '41', 'count': '234'}],
#       'smallest': '1',
#       'count': '16794',
#       'cardinality': '72'},
#      'format': {}},
#     {'id': 559238950,
#      'name': 'Time Period Label',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'time_period_label',
#      'position': 7,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255551,
#      'cachedContents': {'non_null': '16794',
#       'largest': 'Sep 30 - Oct 12, 2020',
#       'null': '0',
#       'top': [{'item': 'Jun 25 - Jul 22, 2024', 'count': '234'},
#        {'item': 'Jul 27 - Aug 8, 2022', 'count': '234'},
#        {'item': 'Feb 1 - Feb 13, 2023', 'count': '234'},
#        {'item': 'Mar 5 - Apr 1, 2024', 'count': '234'},
#        {'item': 'May 28 - Jun 24, 2024', 'count': '234'},
#        {'item': 'Sep 14 - Sep 26, 2022', 'count': '234'},
#        {'item': 'Aug 18 - Aug 30, 2021', 'count': '234'},
#        {'item': 'Mar 30 - Apr 11, 2022', 'count': '234'},
#        {'item': 'Mar 1 - Mar 13, 2023', 'count': '234'},
#        {'item': 'Apr 27 - May 9, 2022', 'count': '234'},
#        {'item': 'Aug 4 - Aug 16, 2021', 'count': '234'},
#        {'item': 'Apr 26 - May 8, 2023', 'count': '234'},
#        {'item': 'Jun 7 - Jun 19, 2023', 'count': '234'},
#        {'item': 'Jul 21 - Aug 2, 2021', 'count': '234'},
#        {'item': 'Sep 1 - Sep 13, 2021', 'count': '234'},
#        {'item': 'Aug 20 - Sep 16, 2024', 'count': '234'},
#        {'item': 'Feb 6 - Mar 4, 2024', 'count': '234'},
#        {'item': 'Oct 18 - Oct 30, 2023', 'count': '234'},
#        {'item': 'Dec 1 - Dec 13, 2021', 'count': '234'},
#        {'item': 'Apr 2 - Apr 29, 2024', 'count': '234'}],
#       'smallest': 'Apr 14 - Apr 26, 2021',
#       'count': '16794',
#       'cardinality': '82'},
#      'format': {}},
#     {'id': 559238951,
#      'name': 'Time Period Start Date',
#      'dataTypeName': 'calendar_date',
#      'description': '',
#      'fieldName': 'time_period_start_date',
#      'position': 8,
#      'renderTypeName': 'calendar_date',
#      'tableColumnId': 130119079,
#      'cachedContents': {'non_null': '16794',
#       'largest': '2024-08-20T00:00:00.000',
#       'null': '0',
#       'top': [{'item': '2024-06-25T00:00:00.000', 'count': '234'},
#        {'item': '2022-06-01T00:00:00.000', 'count': '234'},
#        {'item': '2023-03-29T00:00:00.000', 'count': '234'},
#        {'item': '2022-03-30T00:00:00.000', 'count': '234'},
#        {'item': '2023-07-26T00:00:00.000', 'count': '234'},
#        {'item': '2023-06-07T00:00:00.000', 'count': '234'},
#        {'item': '2021-08-18T00:00:00.000', 'count': '234'},
#        {'item': '2021-07-21T00:00:00.000', 'count': '234'},
#        {'item': '2021-08-04T00:00:00.000', 'count': '234'},
#        {'item': '2022-12-09T00:00:00.000', 'count': '234'},
#        {'item': '2022-07-27T00:00:00.000', 'count': '234'},
#        {'item': '2022-06-29T00:00:00.000', 'count': '234'},
#        {'item': '2023-08-23T00:00:00.000', 'count': '234'},
#        {'item': '2024-04-02T00:00:00.000', 'count': '234'},
#        {'item': '2024-03-05T00:00:00.000', 'count': '234'},
#        {'item': '2023-02-01T00:00:00.000', 'count': '234'},
#        {'item': '2023-04-26T00:00:00.000', 'count': '234'},
#        {'item': '2023-09-20T00:00:00.000', 'count': '234'},
#        {'item': '2022-03-02T00:00:00.000', 'count': '234'},
#        {'item': '2024-04-30T00:00:00.000', 'count': '234'}],
#       'smallest': '2020-04-23T00:00:00.000',
#       'count': '16794',
#       'cardinality': '82'},
#      'format': {'view': 'date'}},
#     {'id': 559238952,
#      'name': 'Time Period End Date',
#      'dataTypeName': 'calendar_date',
#      'description': '',
#      'fieldName': 'time_period_end_date',
#      'position': 9,
#      'renderTypeName': 'calendar_date',
#      'tableColumnId': 130119078,
#      'cachedContents': {'non_null': '16794',
#       'largest': '2024-09-16T00:00:00.000',
#       'null': '0',
#       'top': [{'item': '2022-11-14T00:00:00.000', 'count': '234'},
#        {'item': '2021-08-30T00:00:00.000', 'count': '234'},
#        {'item': '2023-04-10T00:00:00.000', 'count': '234'},
#        {'item': '2024-04-01T00:00:00.000', 'count': '234'},
#        {'item': '2023-01-16T00:00:00.000', 'count': '234'},
#        {'item': '2021-09-13T00:00:00.000', 'count': '234'},
#        {'item': '2023-10-02T00:00:00.000', 'count': '234'},
#        {'item': '2022-03-14T00:00:00.000', 'count': '234'},
#        {'item': '2022-04-11T00:00:00.000', 'count': '234'},
#        {'item': '2022-07-11T00:00:00.000', 'count': '234'},
#        {'item': '2021-08-02T00:00:00.000', 'count': '234'},
#        {'item': '2022-08-08T00:00:00.000', 'count': '234'},
#        {'item': '2024-08-19T00:00:00.000', 'count': '234'},
#        {'item': '2023-08-07T00:00:00.000', 'count': '234'},
#        {'item': '2021-12-13T00:00:00.000', 'count': '234'},
#        {'item': '2023-05-08T00:00:00.000', 'count': '234'},
#        {'item': '2022-05-09T00:00:00.000', 'count': '234'},
#        {'item': '2023-10-30T00:00:00.000', 'count': '234'},
#        {'item': '2021-09-27T00:00:00.000', 'count': '234'},
#        {'item': '2022-02-07T00:00:00.000', 'count': '234'}],
#       'smallest': '2020-05-05T00:00:00.000',
#       'count': '16794',
#       'cardinality': '82'},
#      'format': {'view': 'date'}},
#     {'id': 559238953,
#      'name': 'Value',
#      'dataTypeName': 'number',
#      'description': '',
#      'fieldName': 'value',
#      'position': 10,
#      'renderTypeName': 'number',
#      'tableColumnId': 102255556,
#      'cachedContents': {'non_null': '16087',
#       'largest': '85.2',
#       'null': '707',
#       'top': [{'item': '31.4', 'count': '94'},
#        {'item': '26.5', 'count': '93'},
#        {'item': '27.9', 'count': '90'},
#        {'item': '28', 'count': '86'},
#        {'item': '27.8', 'count': '86'},
#        {'item': '22.5', 'count': '83'},
#        {'item': '28.7', 'count': '83'},
#        {'item': '26.9', 'count': '83'},
#        {'item': '26.2', 'count': '82'},
#        {'item': '25.5', 'count': '82'},
#        {'item': '31.1', 'count': '82'},
#        {'item': '24.5', 'count': '81'},
#        {'item': '27.6', 'count': '81'},
#        {'item': '30.5', 'count': '80'},
#        {'item': '26.7', 'count': '80'},
#        {'item': '27.4', 'count': '80'},
#        {'item': '29.3', 'count': '79'},
#        {'item': '30.1', 'count': '79'},
#        {'item': '29.9', 'count': '78'},
#        {'item': '29.4', 'count': '78'}],
#       'smallest': '4.6',
#       'count': '16794',
#       'cardinality': '605'},
#      'format': {'precisionStyle': 'standard', 'precision': '1'}},
#     {'id': 559238954,
#      'name': 'Low CI',
#      'dataTypeName': 'number',
#      'description': '',
#      'fieldName': 'lowci',
#      'position': 11,
#      'renderTypeName': 'number',
#      'tableColumnId': 102255557,
#      'cachedContents': {'non_null': '16087',
#       'largest': '79.9',
#       'null': '707',
#       'top': [{'item': '25.1', 'count': '99'},
#        {'item': '21.4', 'count': '97'},
#        {'item': '23.4', 'count': '93'},
#        {'item': '25.3', 'count': '92'},
#        {'item': '26.6', 'count': '91'},
#        {'item': '21.3', 'count': '90'},
#        {'item': '22.2', 'count': '89'},
#        {'item': '21.7', 'count': '88'},
#        {'item': '21.5', 'count': '88'},
#        {'item': '24', 'count': '88'},
#        {'item': '24.9', 'count': '87'},
#        {'item': '21.6', 'count': '87'},
#        {'item': '22.5', 'count': '86'},
#        {'item': '22.7', 'count': '84'},
#        {'item': '25.7', 'count': '84'},
#        {'item': '26.4', 'count': '84'},
#        {'item': '25.5', 'count': '83'},
#        {'item': '20.4', 'count': '83'},
#        {'item': '24.2', 'count': '83'},
#        {'item': '26.5', 'count': '83'}],
#       'smallest': '3.3',
#       'count': '16794',
#       'cardinality': '573'},
#      'format': {'precision': '1'}},
#     {'id': 559238955,
#      'name': 'High CI',
#      'dataTypeName': 'number',
#      'description': '',
#      'fieldName': 'highci',
#      'position': 12,
#      'renderTypeName': 'number',
#      'tableColumnId': 102255554,
#      'cachedContents': {'non_null': '16087',
#       'largest': '89.5',
#       'null': '707',
#       'top': [{'item': '31.4', 'count': '92'},
#        {'item': '36.8', 'count': '90'},
#        {'item': '32', 'count': '88'},
#        {'item': '29.3', 'count': '86'},
#        {'item': '31.6', 'count': '86'},
#        {'item': '34.4', 'count': '86'},
#        {'item': '29', 'count': '85'},
#        {'item': '32.3', 'count': '84'},
#        {'item': '32.1', 'count': '84'},
#        {'item': '33.5', 'count': '82'},
#        {'item': '30.9', 'count': '82'},
#        {'item': '33.3', 'count': '82'},
#        {'item': '35.2', 'count': '81'},
#        {'item': '33.1', 'count': '81'},
#        {'item': '29.2', 'count': '80'},
#        {'item': '33.2', 'count': '80'},
#        {'item': '25.4', 'count': '80'},
#        {'item': '35.7', 'count': '79'},
#        {'item': '31.3', 'count': '78'},
#        {'item': '34.6', 'count': '78'}],
#       'smallest': '6',
#       'count': '16794',
#       'cardinality': '641'},
#      'format': {'precision': '1'}},
#     {'id': 559238956,
#      'name': 'Confidence Interval',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'confidence_interval',
#      'position': 13,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255552,
#      'cachedContents': {'non_null': '16087',
#       'largest': '9.9 - 21.0',
#       'null': '707',
#       'top': [{'item': '26.1 - 34.4', 'count': '6'},
#        {'item': '22.1 - 31.0', 'count': '6'},
#        {'item': '17.6 - 24.5', 'count': '6'},
#        {'item': '25.7 - 35.5', 'count': '5'},
#        {'item': '27.2 - 35.9', 'count': '5'},
#        {'item': '24.0 - 32.5', 'count': '5'},
#        {'item': '27.5 - 35.8', 'count': '5'},
#        {'item': '25.7 - 33.1', 'count': '5'},
#        {'item': '26.5 - 34.2', 'count': '5'},
#        {'item': '26.1 - 33.9', 'count': '5'},
#        {'item': '26.4 - 34.9', 'count': '5'},
#        {'item': '31.1 - 41.0', 'count': '5'},
#        {'item': '25.6 - 33.4', 'count': '5'},
#        {'item': '25.0 - 33.3', 'count': '5'},
#        {'item': '22.5 - 31.6', 'count': '5'},
#        {'item': '30.9 - 32.5', 'count': '5'},
#        {'item': '22.3 - 30.5', 'count': '5'},
#        {'item': '30.6 - 32.3', 'count': '5'},
#        {'item': '27.2 - 35.1', 'count': '5'},
#        {'item': '23.6 - 32.2', 'count': '5'}],
#       'smallest': '10.0 - 11.0',
#       'count': '16794',
#       'cardinality': '12515'},
#      'format': {}},
#     {'id': 559238957,
#      'name': 'Quartile Range',
#      'dataTypeName': 'text',
#      'description': '',
#      'fieldName': 'quartile_range',
#      'position': 14,
#      'renderTypeName': 'text',
#      'tableColumnId': 102255553,
#      'cachedContents': {'non_null': '11017',
#       'largest': 'Estimate not reliable',
#       'null': '5777',
#       'top': [{'item': '23.2-27.3', 'count': '37'},
#        {'item': '12.1-13.8', 'count': '27'},
#        {'item': '14.9-19.5', 'count': '27'},
#        {'item': '28.8-31.4', 'count': '27'},
#        {'item': '23.4-25.7', 'count': '27'},
#        {'item': '21.6-26.2', 'count': '26'},
#        {'item': '19.6-21.2', 'count': '26'},
#        {'item': '23.9-29.4', 'count': '26'},
#        {'item': '28.6-31.7', 'count': '26'},
#        {'item': '29.5-32.0', 'count': '26'},
#        {'item': '19.6-21.3', 'count': '25'},
#        {'item': '33.4-36.0', 'count': '25'},
#        {'item': '22.4-24.6', 'count': '25'},
#        {'item': '23.9-26.0', 'count': '25'},
#        {'item': '19.4-21.5', 'count': '25'},
#        {'item': '23.6-29.7', 'count': '25'},
#        {'item': '33.2-35.5', 'count': '25'},
#        {'item': '19.2-20.8', 'count': '25'},
#        {'item': '21.3-22.7', 'count': '25'},
#        {'item': '27.4-29.8', 'count': '25'}],
#       'smallest': '10.0-12.4',
#       'count': '16794',
#       'cardinality': '841'},
#      'format': {}}],
#    'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#    'license': {'name': 'Public Domain U.S. Government',
#     'termsLink': 'https://www.usa.gov/government-works'},
#    'metadata': {'custom_fields': {'Data Quality': {'Geospatial Resolution': 'State',
#       'Suggested Citation': 'National Center for Health Statistics. Indicators of Anxiety or Depression Based on Reported Frequency of Symptoms During Last 7 Days. Data accessed [Last accessed date]. Available from: https://data.cdc.gov/d/8pt5-q6wp.'},
#      'Common Core': {'Contact Email': 'cdcinfo@cdc.gov',
#       'Homepage': 'https://www.cdc.gov/nchs/covid19/pulse/mental-health.htm',
#       'Language': 'en-US',
#       'Contact Name': 'National Center for Health Statistics',
#       'Update Frequency': 'R/P2W',
#       'Temporal Applicability': '2020-08-19/2024-09-16',
#       'Issued': '2020-05-20',
#       'Program Code': '009:020',
#       'Geographic Coverage': 'US',
#       'Publisher': 'National Center for Health Statistics',
#       'Bureau Code': '009:20',
#       'Public Access Level': 'public'}},
#     'rowLabel': 'Estimate of anxiety or depression',
#     'availableDisplayTypes': ['table', 'fatrow', 'page']},
#    'owner': {'id': 'ki96-txhe',
#     'displayName': 'NCHS',
#     'profileImageUrlLarge': '/api/users/ki96-txhe/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/ki96-txhe/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/ki96-txhe/profile_images/TINY',
#     'screenName': 'NCHS',
#     'type': 'interactive',
#     'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#    'query': {},
#    'rights': ['read'],
#    'tableAuthor': {'id': 'ki96-txhe',
#     'displayName': 'NCHS',
#     'profileImageUrlLarge': '/api/users/ki96-txhe/profile_images/LARGE',
#     'profileImageUrlMedium': '/api/users/ki96-txhe/profile_images/THUMB',
#     'profileImageUrlSmall': '/api/users/ki96-txhe/profile_images/TINY',
#     'screenName': 'NCHS',
#     'type': 'interactive',
#     'flags': ['acceptedEula', 'mayBeStoriesCoOwner']},
#    'tags': ['depression', 'anxiety', 'covid-19'],
#    'flags': ['default',
#     'ownerMayBeContacted',
#     'restorable',
#     'restorePossibleForType']}},
#  'data': [['row-bg55_9ag3~k28u',
#    '00000000-0000-0000-3CE1-869377BF2C8A',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'National Estimate',
#    'United States',
#    'United States',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '23.5',
#    '22.7',
#    '24.3',
#    '22.7 - 24.3',
#    None],
#   ['row-54up.86wf-96i2',
#    '00000000-0000-0000-BCEA-D97191E97FCC',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Age',
#    'United States',
#    '18 - 29 years',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '32.7',
#    '30.2',
#    '35.2',
#    '30.2 - 35.2',
#    None],
#   ['row-n4zm.k6qt~nvs5',
#    '00000000-0000-0000-5A5F-DE9322C29F44',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Age',
#    'United States',
#    '30 - 39 years',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.7',
#    '24.1',
#    '27.3',
#    '24.1 - 27.3',
#    None],
#   ['row-cjc8_5q9v-zj6z',
#    '00000000-0000-0000-976D-89DBD361B062',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Age',
#    'United States',
#    '40 - 49 years',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '24.8',
#    '23.3',
#    '26.2',
#    '23.3 - 26.2',
#    None],
#   ['row-jsrf-vxiz~9i6r',
#    '00000000-0000-0000-BDF1-6960841430B0',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Age',
#    'United States',
#    '50 - 59 years',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '23.2',
#    '21.5',
#    '25',
#    '21.5 - 25.0',
#    None],
#   ['row-u4db.ufbx_475v',
#    '00000000-0000-0000-D6A5-01AEBD5B505A',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Age',
#    'United States',
#    '60 - 69 years',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '18.4',
#    '17',
#    '19.7',
#    '17.0 - 19.7',
#    None],
#   ['row-rc9a~38yt.39fm',
#    '00000000-0000-0000-8795-142EFD055110',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Age',
#    'United States',
#    '70 - 79 years',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '13.6',
#    '11.8',
#    '15.5',
#    '11.8 - 15.5',
#    None],
#   ['row-yqge~h35d-ivit',
#    '00000000-0000-0000-8AD9-798C8482D759',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Age',
#    'United States',
#    '80 years and above',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '14.4',
#    '9',
#    '21.4',
#    '9.0 - 21.4',
#    None],
#   ['row-rcig_s2gh_7g2u',
#    '00000000-0000-0000-B3A1-479D201A33C3',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Sex',
#    'United States',
#    'Male',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '20.8',
#    '19.6',
#    '22',
#    '19.6 - 22.0',
#    None],
#   ['row-yz9s.qzty~mbj5',
#    '00000000-0000-0000-E6EB-84388950A5BC',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Sex',
#    'United States',
#    'Female',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '26.1',
#    '25.2',
#    '27.1',
#    '25.2 - 27.1',
#    None],
#   ['row-ktaf-p8wd-htba',
#    '00000000-0000-0000-FB63-6A59A7A4874F',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Hispanic or Latino',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '29.4',
#    '26.8',
#    '32.1',
#    '26.8 - 32.1',
#    None],
#   ['row-ibt2_ktm5_49d4',
#    '00000000-0000-0000-FE86-9A0A09B15815',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic White, single race',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '21.4',
#    '20.6',
#    '22.1',
#    '20.6 - 22.1',
#    None],
#   ['row-xhu5.spjp-dc2h',
#    '00000000-0000-0000-7B8E-003D4A9F7BFD',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic Black, single race',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.6',
#    '23.7',
#    '27.5',
#    '23.7 - 27.5',
#    None],
#   ['row-nbc8-p3n3~cna5',
#    '00000000-0000-0000-E3B3-852C034CE25D',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic Asian, single race',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '23.6',
#    '20.3',
#    '27.1',
#    '20.3 - 27.1',
#    None],
#   ['row-sv4c_m6ma-gecw',
#    '00000000-0000-0000-5DB3-FBEE679528F0',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic, other races and multiple races',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '28.3',
#    '24.8',
#    '32',
#    '24.8 - 32.0',
#    None],
#   ['row-thqf.kfsc_8q6r',
#    '00000000-0000-0000-5D28-7115C54DD5D0',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Education',
#    'United States',
#    'Less than a high school diploma',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '32.7',
#    '27.8',
#    '38',
#    '27.8 - 38.0',
#    None],
#   ['row-zm59_wtzr.zyk6',
#    '00000000-0000-0000-E651-F60E35D0927C',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Education',
#    'United States',
#    'High school diploma or GED',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.4',
#    '23.9',
#    '26.9',
#    '23.9 - 26.9',
#    None],
#   ['row-z3yn.45rj.d7fi',
#    '00000000-0000-0000-B67E-11D046DD902A',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Education',
#    'United States',
#    "Some college/Associate's degree",
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.6',
#    '24.4',
#    '26.9',
#    '24.4 - 26.9',
#    None],
#   ['row-wnue-8a26.8m3r',
#    '00000000-0000-0000-CB3A-1DE31291F609',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By Education',
#    'United States',
#    "Bachelor's degree or higher",
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '17.6',
#    '16.8',
#    '18.4',
#    '16.8 - 18.4',
#    None],
#   ['row-nqvy-p85x~dvmx',
#    '00000000-0000-0000-0E8D-A2EB1B37B7E0',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Alabama',
#    'Alabama',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '18.6',
#    '14.6',
#    '23.1',
#    '14.6 - 23.1',
#    '16.5 - 20.7'],
#   ['row-8qs7_etbv_rvta',
#    '00000000-0000-0000-6526-B827133F67B9',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Alaska',
#    'Alaska',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '19.2',
#    '16.8',
#    '21.8',
#    '16.8 - 21.8',
#    '16.5 - 20.7'],
#   ['row-sifb.xgbp.t39r',
#    '00000000-0000-0000-C3D4-073A4758DE3A',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Arizona',
#    'Arizona',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '22.4',
#    '19.4',
#    '25.5',
#    '19.4 - 25.5',
#    '22.2 - 24.0'],
#   ['row-rg2f_ueci-v6dq',
#    '00000000-0000-0000-722B-EE212CBA2E40',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Arkansas',
#    'Arkansas',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '26.6',
#    '22.3',
#    '31.3',
#    '22.3 - 31.3',
#    '24.1 - 28.7'],
#   ['row-xcgi~dtfq~mynb',
#    '00000000-0000-0000-EBE7-1949D07AF34C',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'California',
#    'California',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.4',
#    '22.5',
#    '28.6',
#    '22.5 - 28.6',
#    '24.1 - 28.7'],
#   ['row-7iwg~irv2_r7bh',
#    '00000000-0000-0000-9387-920D50AF6CF8',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Colorado',
#    'Colorado',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '22',
#    '19.4',
#    '24.9',
#    '19.4 - 24.9',
#    '20.8 - 22.1'],
#   ['row-2y6a~rkza_vf2i',
#    '00000000-0000-0000-2AFA-FAD7097815E2',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Connecticut',
#    'Connecticut',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '24.4',
#    '20.1',
#    '29.1',
#    '20.1 - 29.1',
#    '24.1 - 28.7'],
#   ['row-p4ms.pyys~uqf3',
#    '00000000-0000-0000-EAFC-238F795B1D5E',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Delaware',
#    'Delaware',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '21.1',
#    '17.6',
#    '24.9',
#    '17.6 - 24.9',
#    '20.8 - 22.1'],
#   ['row-6a6g~4xhr_yedu',
#    '00000000-0000-0000-209A-C6BC8DCA86D3',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'District of Columbia',
#    'District of Columbia',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '26.4',
#    '22.1',
#    '31.1',
#    '22.1 - 31.1',
#    '24.1 - 28.7'],
#   ['row-vpad_s6vr_r8y7',
#    '00000000-0000-0000-2E5A-0B77EB93D6DB',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Florida',
#    'Florida',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '22.5',
#    '19.7',
#    '25.4',
#    '19.7 - 25.4',
#    '22.2 - 24.0'],
#   ['row-rpky.te68_hys7',
#    '00000000-0000-0000-C47A-58CDACD40E79',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Georgia',
#    'Georgia',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.6',
#    '21.4',
#    '30.2',
#    '21.4 - 30.2',
#    '24.1 - 28.7'],
#   ['row-hxiq_feza~xn67',
#    '00000000-0000-0000-CDD9-F515792B2535',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Hawaii',
#    'Hawaii',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '20',
#    '14.9',
#    '26.1',
#    '14.9 - 26.1',
#    '16.5 - 20.7'],
#   ['row-qdta.xfvm.xjqu',
#    '00000000-0000-0000-4050-89B708E50F44',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Idaho',
#    'Idaho',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '20.6',
#    '17.3',
#    '24.1',
#    '17.3 - 24.1',
#    '16.5 - 20.7'],
#   ['row-yp78-f4p6-bj4x',
#    '00000000-0000-0000-295E-4FF49B641250',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Illinois',
#    'Illinois',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '23.3',
#    '19.6',
#    '27.2',
#    '19.6 - 27.2',
#    '22.2 - 24.0'],
#   ['row-9c84~pvwq_5rpg',
#    '00000000-0000-0000-8EB6-F21AEEF28A94',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Indiana',
#    'Indiana',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '26.4',
#    '22.1',
#    '31',
#    '22.1 - 31.0',
#    '24.1 - 28.7'],
#   ['row-3btz~wg6j-4772',
#    '00000000-0000-0000-274C-F65A6AC576C8',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Iowa',
#    'Iowa',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '16.5',
#    '13.7',
#    '19.6',
#    '13.7 - 19.6',
#    '16.5 - 20.7'],
#   ['row-dega_9jq5_pdu2',
#    '00000000-0000-0000-675C-77856A496CD4',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Kansas',
#    'Kansas',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '22.1',
#    '18.3',
#    '26.4',
#    '18.3 - 26.4',
#    '20.8 - 22.1'],
#   ['row-74ki-df8m_d5pr',
#    '00000000-0000-0000-0F8A-18162124947E',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Kentucky',
#    'Kentucky',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '23.2',
#    '19.4',
#    '27.4',
#    '19.4 - 27.4',
#    '22.2 - 24.0'],
#   ['row-4xdm~4wpm.cuxn',
#    '00000000-0000-0000-D910-441997C9F417',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Louisiana',
#    'Louisiana',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '28.1',
#    '24.1',
#    '32.4',
#    '24.1 - 32.4',
#    '24.1 - 28.7'],
#   ['row-mp6b-9jyf_64ew',
#    '00000000-0000-0000-83E3-F1E05B46B6FB',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Maine',
#    'Maine',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '19.5',
#    '16',
#    '23.5',
#    '16.0 - 23.5',
#    '16.5 - 20.7'],
#   ['row-k6j6-8j74_swdi',
#    '00000000-0000-0000-BAA5-8F60EBB74E49',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Maryland',
#    'Maryland',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '20.9',
#    '17.9',
#    '24.1',
#    '17.9 - 24.1',
#    '20.8 - 22.1'],
#   ['row-w55y_y54i-zwag',
#    '00000000-0000-0000-4AC5-74C75B088293',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Massachusetts',
#    'Massachusetts',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.9',
#    '22.7',
#    '29.4',
#    '22.7 - 29.4',
#    '24.1 - 28.7'],
#   ['row-7rxa~7f9t-yaif',
#    '00000000-0000-0000-2524-8F6E97CF032C',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Michigan',
#    'Michigan',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '25.5',
#    '22',
#    '29.4',
#    '22.0 - 29.4',
#    '24.1 - 28.7'],
#   ['row-a98e~wraj-6p2p',
#    '00000000-0000-0000-1F2B-1ACCDCA3B26A',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Minnesota',
#    'Minnesota',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '20.4',
#    '17.7',
#    '23.4',
#    '17.7 - 23.4',
#    '16.5 - 20.7'],
#   ['row-hjf6-3c8g.x76v',
#    '00000000-0000-0000-A306-8BD89D9A4A29',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Mississippi',
#    'Mississippi',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '22.9',
#    '18.7',
#    '27.6',
#    '18.7 - 27.6',
#    '22.2 - 24.0'],
#   ['row-ccis~fjpg-ejfh',
#    '00000000-0000-0000-5889-6C6A0B71261C',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Missouri',
#    'Missouri',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '21',
#    '17.9',
#    '24.5',
#    '17.9 - 24.5',
#    '20.8 - 22.1'],
#   ['row-5uwe.ihqf~c47r',
#    '00000000-0000-0000-19E0-94360842D74C',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Montana',
#    'Montana',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '18.2',
#    '14.9',
#    '21.8',
#    '14.9 - 21.8',
#    '16.5 - 20.7'],
#   ['row-3kx6~fuyz_ifx9',
#    '00000000-0000-0000-0EDC-6E8076F977D5',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Nebraska',
#    'Nebraska',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '19.1',
#    '15.3',
#    '23.3',
#    '15.3 - 23.3',
#    '16.5 - 20.7'],
#   ['row-e8ed~87bq_aik4',
#    '00000000-0000-0000-706D-099E960E2D14',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Nevada',
#    'Nevada',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '23.6',
#    '19.1',
#    '28.7',
#    '19.1 - 28.7',
#    '22.2 - 24.0'],
#   ['row-73df~k4ua_58au',
#    '00000000-0000-0000-90AC-8666037322E0',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'New Hampshire',
#    'New Hampshire',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '19.5',
#    '16.5',
#    '22.7',
#    '16.5 - 22.7',
#    '16.5 - 20.7'],
#   ['row-empq.dy8t~uegk',
#    '00000000-0000-0000-AD7D-AEC437ADFFF7',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'New Jersey',
#    'New Jersey',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '23.6',
#    '20.4',
#    '27',
#    '20.4 - 27.0',
#    '22.2 - 24.0'],
#   ['row-jzyd-zh96-dzdx',
#    '00000000-0000-0000-E217-C762150543A3',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'New Mexico',
#    'New Mexico',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '22.4',
#    '18.3',
#    '26.9',
#    '18.3 - 26.9',
#    '22.2 - 24.0'],
#   ['row-8cef-5epz~wz67',
#    '00000000-0000-0000-3CFC-D18222BB1226',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'New York',
#    'New York',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '28.7',
#    '24.6',
#    '33.1',
#    '24.6 - 33.1',
#    '24.1 - 28.7'],
#   ['row-zb5r_hqi6.n7t2',
#    '00000000-0000-0000-54BA-DB489AA88E63',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'North Carolina',
#    'North Carolina',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '21.1',
#    '17.1',
#    '25.6',
#    '17.1 - 25.6',
#    '20.8 - 22.1'],
#   ['row-wyer.c466_sebi',
#    '00000000-0000-0000-AB94-1290EF7B3CBC',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'North Dakota',
#    'North Dakota',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '17',
#    '13.7',
#    '20.7',
#    '13.7 - 20.7',
#    '16.5 - 20.7'],
#   ['row-kyg2-t35y_g8k3',
#    '00000000-0000-0000-3B5A-A0F37AB98D45',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Ohio',
#    'Ohio',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '21.2',
#    '18.2',
#    '24.5',
#    '18.2 - 24.5',
#    '20.8 - 22.1'],
#   ['row-hmak~rhkg_8mji',
#    '00000000-0000-0000-3140-6A344C1B112C',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Oklahoma',
#    'Oklahoma',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '20.8',
#    '16.4',
#    '25.7',
#    '16.4 - 25.7',
#    '20.8 - 22.1'],
#   ['row-9rhm_zfhc~gaqn',
#    '00000000-0000-0000-C270-8A5807DD424F',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Oregon',
#    'Oregon',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '22.5',
#    '19.7',
#    '25.4',
#    '19.7 - 25.4',
#    '22.2 - 24.0'],
#   ['row-hftu~gvbx-i3my',
#    '00000000-0000-0000-E0EA-56A85A8931BC',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Pennsylvania',
#    'Pennsylvania',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '24.7',
#    '21.6',
#    '28.1',
#    '21.6 - 28.1',
#    '24.1 - 28.7'],
#   ['row-u5vx~3ut4-8vhd',
#    '00000000-0000-0000-A04B-4E8950DD0362',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'Rhode Island',
#    'Rhode Island',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '24.5',
#    '19.9',
#    '29.7',
#    '19.9 - 29.7',
#    '24.1 - 28.7'],
#   ['row-bxct~bi6w_tpwg',
#    '00000000-0000-0000-416B-C804431B03A7',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
#    'South Carolina',
#    'South Carolina',
#    '1',
#    '1',
#    'Apr 23 - May 5, 2020',
#    '2020-04-23T00:00:00',
#    '2020-05-05T00:00:00',
#    '21.6',
#    '17.9',
#    '25.7',
#    '17.9 - 25.7',
#    '20.8 - 22.1'],
#   ['row-8tbp~7ct2_ncr5',
#    '00000000-0000-0000-E40B-C803705318F2',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Depressive Disorder',
#    'By State',
# ...
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '31.8',
#    '28.3',
#    '35.5',
#    '28.3 - 35.5',
#    '31.8-37.1'],
#   ['row-kb4c_scsq-nqb3',
#    '00000000-0000-0000-00E6-E06382DD4640',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'New Mexico',
#    'New Mexico',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '37.1',
#    '32.1',
#    '42.3',
#    '32.1 - 42.3',
#    '31.8-37.1'],
#   ['row-imsr.s7f9~3j7d',
#    '00000000-0000-0000-6255-B351B4BE1A85',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'New York',
#    'New York',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '29.8',
#    '26.4',
#    '33.4',
#    '26.4 - 33.4',
#    '29.7-31.7'],
#   ['row-24ia.fn34-gz9k',
#    '00000000-0000-0000-4A7A-06734F4074AF',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'North Carolina',
#    'North Carolina',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '29.6',
#    '26.1',
#    '33.3',
#    '26.1 - 33.3',
#    '26.8-29.6'],
#   ['row-3frm~ytxy_b7gp',
#    '00000000-0000-0000-D3C6-DEE3B609BEC7',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'North Dakota',
#    'North Dakota',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '18.4',
#    '15',
#    '22.2',
#    '15.0 - 22.2',
#    '18.4-26.7'],
#   ['row-cmap_bxpd~mypb',
#    '00000000-0000-0000-8ED0-4B60BFE54AB5',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Ohio',
#    'Ohio',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '29.6',
#    '25.4',
#    '34.1',
#    '25.4 - 34.1',
#    '26.8-29.6'],
#   ['row-3wnm.tt6g~mv9u',
#    '00000000-0000-0000-CBDF-04BA51C38994',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Oklahoma',
#    'Oklahoma',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '31.7',
#    '28.1',
#    '35.6',
#    '28.1 - 35.6',
#    '29.7-31.7'],
#   ['row-nk8q-dpcy~sw97',
#    '00000000-0000-0000-D75A-B49F5BA56171',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Oregon',
#    'Oregon',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '35.3',
#    '31.5',
#    '39.2',
#    '31.5 - 39.2',
#    '31.8-37.1'],
#   ['row-f6j8-8q2c-fqu7',
#    '00000000-0000-0000-5D11-1F4E559E96B8',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Pennsylvania',
#    'Pennsylvania',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '31.4',
#    '27',
#    '36',
#    '27.0 - 36.0',
#    '29.7-31.7'],
#   ['row-n6vr~5zkz.mb6s',
#    '00000000-0000-0000-D89E-F3DAF1BEAA28',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Rhode Island',
#    'Rhode Island',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '30.8',
#    '25.6',
#    '36.5',
#    '25.6 - 36.5',
#    '29.7-31.7'],
#   ['row-43yr_g3n7~rnxk',
#    '00000000-0000-0000-2A30-B0BA15A00413',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'South Carolina',
#    'South Carolina',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '29.2',
#    '24.4',
#    '34.4',
#    '24.4 - 34.4',
#    '26.8-29.6'],
#   ['row-vtsm~3t6q~a69r',
#    '00000000-0000-0000-3E37-322C3AC0B63A',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'South Dakota',
#    'South Dakota',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '26.3',
#    '21.8',
#    '31.1',
#    '21.8 - 31.1',
#    '18.4-26.7'],
#   ['row-wx3m_4uyj~qm3x',
#    '00000000-0000-0000-7505-B4D347DC3204',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Tennessee',
#    'Tennessee',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '30.4',
#    '26.4',
#    '34.6',
#    '26.4 - 34.6',
#    '29.7-31.7'],
#   ['row-9z4v.6pq2~84pm',
#    '00000000-0000-0000-7652-5AF654338A17',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Texas',
#    'Texas',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '31.1',
#    '27.7',
#    '34.6',
#    '27.7 - 34.6',
#    '29.7-31.7'],
#   ['row-c7xt-u8gz.9sq4',
#    '00000000-0000-0000-E9AA-0DDC363FC087',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Utah',
#    'Utah',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '29.7',
#    '26.7',
#    '32.8',
#    '26.7 - 32.8',
#    '29.7-31.7'],
#   ['row-ynax.t2gz_khra',
#    '00000000-0000-0000-4FC4-E6DBBF0C63FE',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Vermont',
#    'Vermont',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '31.8',
#    '25.5',
#    '38.6',
#    '25.5 - 38.6',
#    '31.8-37.1'],
#   ['row-dub7_3ed7-xsg6',
#    '00000000-0000-0000-5C44-72CDD63DE77F',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Virginia',
#    'Virginia',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '28.3',
#    '25',
#    '31.7',
#    '25.0 - 31.7',
#    '26.8-29.6'],
#   ['row-d46a~zu57~khij',
#    '00000000-0000-0000-498F-5BCEC46D8B66',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Washington',
#    'Washington',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '31.7',
#    '28.1',
#    '35.5',
#    '28.1 - 35.5',
#    '29.7-31.7'],
#   ['row-26us~qndq-hcv9',
#    '00000000-0000-0000-13C6-0E92267D854E',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'West Virginia',
#    'West Virginia',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '33.6',
#    '28',
#    '39.5',
#    '28.0 - 39.5',
#    '31.8-37.1'],
#   ['row-66a4-3ehq~4qkd',
#    '00000000-0000-0000-2640-DBCBD94A2FFC',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Wisconsin',
#    'Wisconsin',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '22.7',
#    '19.3',
#    '26.3',
#    '19.3 - 26.3',
#    '18.4-26.7'],
#   ['row-gjvk-q4ak.w3t2',
#    '00000000-0000-0000-83E3-326749DFE1E5',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder',
#    'By State',
#    'Wyoming',
#    'Wyoming',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '25.3',
#    '21.2',
#    '29.7',
#    '21.2 - 29.7',
#    '18.4-26.7'],
#   ['row-r7j6_hacc.5phg',
#    '00000000-0000-0000-1331-44FEF60073CD',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'National Estimate',
#    'United States',
#    'United States',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '35.5',
#    '34.8',
#    '36.1',
#    '34.8 - 36.1',
#    None],
#   ['row-q4xb.au38~ujb7',
#    '00000000-0000-0000-3904-9C761D3039CE',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Age',
#    'United States',
#    '18 - 29 years',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '49.3',
#    '47.4',
#    '51.2',
#    '47.4 - 51.2',
#    None],
#   ['row-3ata_s8ab_3fxw',
#    '00000000-0000-0000-9F95-35D2708E45EC',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Age',
#    'United States',
#    '30 - 39 years',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '40.6',
#    '39.2',
#    '42',
#    '39.2 - 42.0',
#    None],
#   ['row-3w2p-6h48~pkm6',
#    '00000000-0000-0000-5D2F-420C640A3954',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Age',
#    'United States',
#    '40 - 49 years',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '36.9',
#    '35.3',
#    '38.6',
#    '35.3 - 38.6',
#    None],
#   ['row-ms59.rreg_fza5',
#    '00000000-0000-0000-0256-49F71C3330E2',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Age',
#    'United States',
#    '50 - 59 years',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '33.6',
#    '31.9',
#    '35.4',
#    '31.9 - 35.4',
#    None],
#   ['row-8vsj.s4bi_u4uc',
#    '00000000-0000-0000-39A7-BF91BF2C3D60',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Age',
#    'United States',
#    '60 - 69 years',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '27',
#    '25.6',
#    '28.5',
#    '25.6 - 28.5',
#    None],
#   ['row-38b9.ewvk.9u4b',
#    '00000000-0000-0000-B1F8-D148EDF76A91',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Age',
#    'United States',
#    '70 - 79 years',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '21.7',
#    '19.3',
#    '24.2',
#    '19.3 - 24.2',
#    None],
#   ['row-86i4-yiet-sgx6',
#    '00000000-0000-0000-023B-0012E255B469',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Age',
#    'United States',
#    '80 years and above',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '19.2',
#    '14.7',
#    '24.4',
#    '14.7 - 24.4',
#    None],
#   ['row-wrbs_qfkj_u89f',
#    '00000000-0000-0000-0CD6-22F22CBC14FA',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Sex',
#    'United States',
#    'Male',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '31.1',
#    '30.2',
#    '32.1',
#    '30.2 - 32.1',
#    None],
#   ['row-h8vx_vdrx-srhd',
#    '00000000-0000-0000-C42C-8DF46276B6CE',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Sex',
#    'United States',
#    'Female',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '39.6',
#    '38.9',
#    '40.3',
#    '38.9 - 40.3',
#    None],
#   ['row-xa3g-tj4u~nik6',
#    '00000000-0000-0000-7241-EFB337C2B81F',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Hispanic or Latino',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '38.3',
#    '36.2',
#    '40.4',
#    '36.2 - 40.4',
#    None],
#   ['row-g62y-zcvx-556m',
#    '00000000-0000-0000-1232-04C133858082',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic White, single race',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '33.1',
#    '32.3',
#    '33.9',
#    '32.3 - 33.9',
#    None],
#   ['row-2iqg~f2jp~uz2q',
#    '00000000-0000-0000-A344-5A89BF04D036',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic Black, single race',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '40.5',
#    '38.3',
#    '42.7',
#    '38.3 - 42.7',
#    None],
#   ['row-yjrj_zd4a~sc4w',
#    '00000000-0000-0000-DD72-68C844F42CBC',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic Asian, single race',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '34.2',
#    '31.6',
#    '37',
#    '31.6 - 37.0',
#    None],
#   ['row-xpfv_rfuj_8buu',
#    '00000000-0000-0000-347F-4926C6517B3A',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Race/Hispanic ethnicity',
#    'United States',
#    'Non-Hispanic, other races and multiple races',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '49.6',
#    '45.9',
#    '53.4',
#    '45.9 - 53.4',
#    None],
#   ['row-rtpa-2efw.n4ku',
#    '00000000-0000-0000-EBCD-B9AF169E9683',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Education',
#    'United States',
#    'Less than a high school diploma',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '43.9',
#    '40.4',
#    '47.5',
#    '40.4 - 47.5',
#    None],
#   ['row-hbuy~24ma-jddf',
#    '00000000-0000-0000-CC55-203F99104567',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Education',
#    'United States',
#    'High school diploma or GED',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '36.7',
#    '35.1',
#    '38.3',
#    '35.1 - 38.3',
#    None],
#   ['row-si6g-gxcv_e4i5',
#    '00000000-0000-0000-BE5C-F9014353A0E9',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Education',
#    'United States',
#    "Some college/Associate's degree",
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '38.3',
#    '37.2',
#    '39.4',
#    '37.2 - 39.4',
#    None],
#   ['row-cujx.xsgq-jin7',
#    '00000000-0000-0000-86DB-FF70FA412EB4',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By Education',
#    'United States',
#    "Bachelor's degree or higher",
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '29.4',
#    '28.5',
#    '30.3',
#    '28.5 - 30.3',
#    None],
#   ['row-ac9c-hmda.8vyj',
#    '00000000-0000-0000-2AAC-242A0505CA45',
#    0,
#    1728050795,
#    None,
#    1728050795,
#    None,
#    '{ }',
#    'Symptoms of Anxiety Disorder or Depressive Disorder',
#    'By State',
#    'Alabama',
#    'Alabama',
#    '1',
#    '5',
#    'May 28 - June 2, 2020',
#    '2020-05-28T00:00:00',
#    '2020-06-02T00:00:00',
#    '37.5',
#    '32.6',
#    '42.6',
#    '32.6 - 42.6',
#    '37.0-40.0'],
#   ...]}

# %%
pd.set_option('display.max_columns', None)

# Column names from the JSON file
columns = [col["name"] for col in data["meta"]["view"]["columns"]]
rows = data["data"]

# JSON file into data frame
indicators = pd.DataFrame(rows, columns=columns)
indicators.head()
# Out:
#                   sid                                    id  position  \
# 0  row-bg55_9ag3~k28u  00000000-0000-0000-3CE1-869377BF2C8A         0
# 1  row-54up.86wf-96i2  00000000-0000-0000-BCEA-D97191E97FCC         0
# 2  row-n4zm.k6qt~nvs5  00000000-0000-0000-5A5F-DE9322C29F44         0
# 3  row-cjc8_5q9v-zj6z  00000000-0000-0000-976D-89DBD361B062         0
# 4  row-jsrf-vxiz~9i6r  00000000-0000-0000-BDF1-6960841430B0         0
#
#    created_at created_meta  updated_at updated_meta meta  \
# 0  1728050795         None  1728050795         None  { }
# 1  1728050795         None  1728050795         None  { }
# 2  1728050795         None  1728050795         None  { }
# 3  1728050795         None  1728050795         None  { }
# 4  1728050795         None  1728050795         None  { }
#
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup Phase Time Period     Time Period Label  \
# 0  United States     1           1  Apr 23 - May 5, 2020
# 1  18 - 29 years     1           1  Apr 23 - May 5, 2020
# 2  30 - 39 years     1           1  Apr 23 - May 5, 2020
# 3  40 - 49 years     1           1  Apr 23 - May 5, 2020
# 4  50 - 59 years     1           1  Apr 23 - May 5, 2020
#
#   Time Period Start Date Time Period End Date Value Low CI High CI  \
# 0    2020-04-23T00:00:00  2020-05-05T00:00:00  23.5   22.7    24.3
# 1    2020-04-23T00:00:00  2020-05-05T00:00:00  32.7   30.2    35.2
# 2    2020-04-23T00:00:00  2020-05-05T00:00:00  25.7   24.1    27.3
# 3    2020-04-23T00:00:00  2020-05-05T00:00:00  24.8   23.3    26.2
# 4    2020-04-23T00:00:00  2020-05-05T00:00:00  23.2   21.5      25
#
#   Confidence Interval Quartile Range
# 0         22.7 - 24.3           None
# 1         30.2 - 35.2           None
# 2         24.1 - 27.3           None
# 3         23.3 - 26.2           None
# 4         21.5 - 25.0           None

# %%
indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16794 entries, 0 to 16793
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sid                     16794 non-null  object
#  1   id                      16794 non-null  object
#  2   position                16794 non-null  int64
#  3   created_at              16794 non-null  int64
#  4   created_meta            0 non-null      object
#  5   updated_at              16794 non-null  int64
#  6   updated_meta            0 non-null      object
#  7   meta                    16794 non-null  object
#  8   Indicator               16794 non-null  object
#  9   Group                   16794 non-null  object
#  10  State                   16794 non-null  object
#  11  Subgroup                16794 non-null  object
#  12  Phase                   16794 non-null  object
#  13  Time Period             16794 non-null  object
#  14  Time Period Label       16794 non-null  object
#  15  Time Period Start Date  16794 non-null  object
#  16  Time Period End Date    16794 non-null  object
#  17  Value                   16087 non-null  object
#  18  Low CI                  16087 non-null  object
#  19  High CI                 16087 non-null  object
#  20  Confidence Interval     16087 non-null  object
#  21  Quartile Range          11017 non-null  object
# dtypes: int64(3), object(19)
# memory usage: 2.8+ MB

# %%
indicators.describe()
# Out:
#        position    created_at    updated_at
# count   16794.0  1.679400e+04  1.679400e+04
# mean        0.0  1.728051e+09  1.728051e+09
# std         0.0  0.000000e+00  0.000000e+00
# min         0.0  1.728051e+09  1.728051e+09
# 25%         0.0  1.728051e+09  1.728051e+09
# 50%         0.0  1.728051e+09  1.728051e+09
# 75%         0.0  1.728051e+09  1.728051e+09
# max         0.0  1.728051e+09  1.728051e+09

# %%
# Dropping columns that are not necessary for analysis
drop_columns = indicators[["sid", "position", "created_at", "created_meta", "updated_at", "meta", "updated_meta", "Time Period Label"]]
indicators = indicators.drop(columns=drop_columns)
indicators.head()
# Out:
#                                      id                        Indicator  \
# 0  00000000-0000-0000-3CE1-869377BF2C8A  Symptoms of Depressive Disorder
# 1  00000000-0000-0000-BCEA-D97191E97FCC  Symptoms of Depressive Disorder
# 2  00000000-0000-0000-5A5F-DE9322C29F44  Symptoms of Depressive Disorder
# 3  00000000-0000-0000-976D-89DBD361B062  Symptoms of Depressive Disorder
# 4  00000000-0000-0000-BDF1-6960841430B0  Symptoms of Depressive Disorder
#
#                Group          State       Subgroup Phase Time Period  \
# 0  National Estimate  United States  United States     1           1
# 1             By Age  United States  18 - 29 years     1           1
# 2             By Age  United States  30 - 39 years     1           1
# 3             By Age  United States  40 - 49 years     1           1
# 4             By Age  United States  50 - 59 years     1           1
#
#   Time Period Start Date Time Period End Date Value Low CI High CI  \
# 0    2020-04-23T00:00:00  2020-05-05T00:00:00  23.5   22.7    24.3
# 1    2020-04-23T00:00:00  2020-05-05T00:00:00  32.7   30.2    35.2
# 2    2020-04-23T00:00:00  2020-05-05T00:00:00  25.7   24.1    27.3
# 3    2020-04-23T00:00:00  2020-05-05T00:00:00  24.8   23.3    26.2
# 4    2020-04-23T00:00:00  2020-05-05T00:00:00  23.2   21.5      25
#
#   Confidence Interval Quartile Range
# 0         22.7 - 24.3           None
# 1         30.2 - 35.2           None
# 2         24.1 - 27.3           None
# 3         23.3 - 26.2           None
# 4         21.5 - 25.0           None

# %%
indicators["Time Period Start Date"] = pd.to_datetime(indicators["Time Period Start Date"])
indicators["Time Period End Date"] = pd.to_datetime(indicators["Time Period End Date"])
indicators.head()
# Out:
#                                      id                        Indicator  \
# 0  00000000-0000-0000-3CE1-869377BF2C8A  Symptoms of Depressive Disorder
# 1  00000000-0000-0000-BCEA-D97191E97FCC  Symptoms of Depressive Disorder
# 2  00000000-0000-0000-5A5F-DE9322C29F44  Symptoms of Depressive Disorder
# 3  00000000-0000-0000-976D-89DBD361B062  Symptoms of Depressive Disorder
# 4  00000000-0000-0000-BDF1-6960841430B0  Symptoms of Depressive Disorder
#
#                Group          State       Subgroup Phase Time Period  \
# 0  National Estimate  United States  United States     1           1
# 1             By Age  United States  18 - 29 years     1           1
# 2             By Age  United States  30 - 39 years     1           1
# 3             By Age  United States  40 - 49 years     1           1
# 4             By Age  United States  50 - 59 years     1           1
#
#   Time Period Start Date Time Period End Date Value Low CI High CI  \
# 0             2020-04-23           2020-05-05  23.5   22.7    24.3
# 1             2020-04-23           2020-05-05  32.7   30.2    35.2
# 2             2020-04-23           2020-05-05  25.7   24.1    27.3
# 3             2020-04-23           2020-05-05  24.8   23.3    26.2
# 4             2020-04-23           2020-05-05  23.2   21.5      25
#
#   Confidence Interval Quartile Range
# 0         22.7 - 24.3           None
# 1         30.2 - 35.2           None
# 2         24.1 - 27.3           None
# 3         23.3 - 26.2           None
# 4         21.5 - 25.0           None

# %%
indicators["Start year"] = indicators["Time Period Start Date"].dt.year

# %%
indicators["Time Period Start Date"].value_counts()
# Out:
# 2021-09-15    234
# 2023-02-01    234
# 2022-12-09    234
# 2022-11-02    234
# 2022-10-05    234
#              ...
# 2021-07-06     63
# 2021-10-12     63
# 2020-07-22     57
# 2020-12-22     57
# 2021-03-30     57
# Name: Time Period Start Date, Length: 82, dtype: int64

# %%
indicators["End year"] = indicators["Time Period End Date"].dt.year

# %%
indicators["Days count of symptoms"] = (indicators["Time Period End Date"] - indicators["Time Period Start Date"]).dt.days
indicators["Days count of symptoms"].value_counts()
# Out:
# 12    11442
# 5      2310
# 27     2163
# 10      234
# 14      177
# 6       162
# 20       81
# 8        81
# 42       81
# 49       63
# Name: Days count of symptoms, dtype: int64

# %%
indicators["Symtoms during the same year"] = indicators["End year"]- indicators["Start year"]

indicators["Symtoms during the same year"] = np.where(
    indicators["End year"] - indicators["Start year"] == 0, "Yes", "No")

# %%
indicators["Subgroup"].value_counts()
# Out:
# United States                      246
# Hispanic or Latino                 246
# 18 - 29 years                      246
# Bachelor's degree or higher        246
# Some college/Associate's degree    246
#                                   ...
# Cis-gender female                  132
# Transgender                        132
# Gay or lesbian                     132
# Straight                           132
# Bisexual                           132
# Name: Subgroup, Length: 78, dtype: int64

# %%
def checkage(row):
    subgroup = row["Subgroup"]
    return "Yes" if subgroup[0].isdigit() else "No"

indicators["Related to Age"] = indicators.apply(checkage, axis=1)
indicators["Related to Age"]
# Out:
# 0         No
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 16789     No
# 16790     No
# 16791     No
# 16792     No
# 16793     No
# Name: Related to Age, Length: 16794, dtype: object

# %%
indicators["Group"].value_counts()
# Out:
# By State                      11016
# By Age                         1722
# By Race/Hispanic ethnicity     1230
# By Education                    984
# By Sex                          492
# By Gender identity              396
# By Sexual orientation           396
# By Disability status            312
# National Estimate               246
# Name: Group, dtype: int64

# %%
indicators[["Start Age", "End Age"]] = indicators["Subgroup"].str.extract(r"(\d+)\s*-\s*(\d+)")
indicators[["Start Age", "End Age"]] = indicators[["Start Age", "End Age"]].replace({np.nan: 0})
indicators[["Start Age", "End Age"]]
# Out:
#       Start Age End Age
# 0             0       0
# 1            18      29
# 2            30      39
# 3            40      49
# 4            50      59
# ...         ...     ...
# 16789         0       0
# 16790         0       0
# 16791         0       0
# 16792         0       0
# 16793         0       0
#
# [16794 rows x 2 columns]

# %%
indicators["Phase"].value_counts()
# Out:
# 1                        2520
# 3.1                      1998
# 3.2                      1404
# 3.0 (Jan 6 - Mar 29)     1260
# 2                        1050
# 4.1                       936
# 3.0 (Oct 28 - Dec 21)     840
# 3.7                       702
# 4                         702
# 3.9                       702
# 3.8                       702
# 3.4                       702
# 3.6                       702
# 3.5                       702
# -1                        702
# 3.3                       702
# 4.2                       468
# Name: Phase, dtype: int64

# %%
indicators["Phase"] = pd.to_numeric(indicators["Phase"], errors='coerce')

# %%
indicators["Phase"] = indicators["Phase"].fillna(3.0)

# %%
indicators["Phase"].value_counts()
# Out:
#  1.0    2520
#  3.0    2100
#  3.1    1998
#  3.2    1404
#  2.0    1050
#  4.1     936
# -1.0     702
#  3.3     702
#  3.4     702
#  3.5     702
#  3.6     702
#  3.7     702
#  3.8     702
#  3.9     702
#  4.0     702
#  4.2     468
# Name: Phase, dtype: int64

# %%
indicators["Phase"].value_counts()
# Out:
#  1.0    2520
#  3.0    2100
#  3.1    1998
#  3.2    1404
#  2.0    1050
#  4.1     936
# -1.0     702
#  3.3     702
#  3.4     702
#  3.5     702
#  3.6     702
#  3.7     702
#  3.8     702
#  3.9     702
#  4.0     702
#  4.2     468
# Name: Phase, dtype: int64

# %%
indicators.tail()
# Out:
#                                          id  \
# 16789  00000000-0000-0000-E9BB-21CBDA3DE35D
# 16790  00000000-0000-0000-7667-7C217E2842BF
# 16791  00000000-0000-0000-7B0A-ED227968BED7
# 16792  00000000-0000-0000-DF47-DF7C1F6C02E8
# 16793  00000000-0000-0000-B7F5-FBCA895109C3
#
#                                                Indicator     Group  \
# 16789  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 16790  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 16791  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 16792  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 16793  Symptoms of Anxiety Disorder or Depressive Dis...  By State
#
#                State       Subgroup  Phase Time Period Time Period Start Date  \
# 16789       Virginia       Virginia    4.2          72             2024-08-20
# 16790     Washington     Washington    4.2          72             2024-08-20
# 16791  West Virginia  West Virginia    4.2          72             2024-08-20
# 16792      Wisconsin      Wisconsin    4.2          72             2024-08-20
# 16793        Wyoming        Wyoming    4.2          72             2024-08-20
#
#       Time Period End Date Value Low CI High CI Confidence Interval  \
# 16789           2024-09-16  20.8   17.4    24.5         17.4 - 24.5
# 16790           2024-09-16  19.9   17.4    22.6         17.4 - 22.6
# 16791           2024-09-16  26.3   21.5    31.4         21.5 - 31.4
# 16792           2024-09-16    17   13.4    21.2         13.4 - 21.2
# 16793           2024-09-16  25.6   19.3    32.8         19.3 - 32.8
#
#       Quartile Range  Start year  End year  Days count of symptoms  \
# 16789      19.5-21.5        2024      2024                      27
# 16790      19.5-21.5        2024      2024                      27
# 16791      23.1-27.8        2024      2024                      27
# 16792      16.6-19.4        2024      2024                      27
# 16793      23.1-27.8        2024      2024                      27
#
#       Symtoms during the same year Related to Age Start Age End Age
# 16789                          Yes             No         0       0
# 16790                          Yes             No         0       0
# 16791                          Yes             No         0       0
# 16792                          Yes             No         0       0
# 16793                          Yes             No         0       0

# %%
indicators["Quartile Range"].value_counts()
# Out:
# 23.2-27.3                37
# 23.4-25.7                27
# 28.8-31.4                27
# 14.9-19.5                27
# 12.1-13.8                27
#                          ..
# 29.4-34.2                10
# 38.0-43.5                10
# 23.9-25.7                10
# 32.4-33.7                 9
# Estimate not reliable     1
# Name: Quartile Range, Length: 841, dtype: int64

# %%
# Null values from CSV file
indicators.isna().sum()
# Out:
# id                                 0
# Indicator                          0
# Group                              0
# State                              0
# Subgroup                           0
# Phase                              0
# Time Period                        0
# Time Period Start Date             0
# Time Period End Date               0
# Value                            707
# Low CI                           707
# High CI                          707
# Confidence Interval              707
# Quartile Range                  5777
# Start year                         0
# End year                           0
# Days count of symptoms             0
# Symtoms during the same year       0
# Related to Age                     0
# Start Age                          0
# End Age                            0
# dtype: int64

# %%
indicators["Value"] = indicators["Value"].fillna(0)
indicators["Low CI"] = indicators["Low CI"].fillna(0)
indicators["High CI"] = indicators["High CI"].fillna(0)
indicators["Confidence Interval"] = indicators["Confidence Interval"].fillna(0)
indicators["Quartile Range"] = indicators["Quartile Range"].fillna(0)
indicators["Start Age"].fillna(0)
indicators["End Age"].fillna("N/A")
indicators["End Age"]
# Out:
# 0         0
# 1        29
# 2        39
# 3        49
# 4        59
#          ..
# 16789     0
# 16790     0
# 16791     0
# 16792     0
# 16793     0
# Name: End Age, Length: 16794, dtype: object

# %%
by_age = indicators[indicators["Group"].str.contains("By Age", case=False)].copy()
by_age["Group"] = by_age["Group"].str.strip()
by_age.head()

by_age["Subgroup"].shape
indicators.update(by_age)


# Null values from CSV file
indicators.isna().sum()
# Out:
# id                              0
# Indicator                       0
# Group                           0
# State                           0
# Subgroup                        0
# Phase                           0
# Time Period                     0
# Time Period Start Date          0
# Time Period End Date            0
# Value                           0
# Low CI                          0
# High CI                         0
# Confidence Interval             0
# Quartile Range                  0
# Start year                      0
# End year                        0
# Days count of symptoms          0
# Symtoms during the same year    0
# Related to Age                  0
# Start Age                       0
# End Age                         0
# dtype: int64

# %%
by_age = indicators[indicators["Group"].str.contains("By Age", case=False)]

# %%
by_age.head()
# Out:
#                                      id                        Indicator  \
# 1  00000000-0000-0000-BCEA-D97191E97FCC  Symptoms of Depressive Disorder
# 2  00000000-0000-0000-5A5F-DE9322C29F44  Symptoms of Depressive Disorder
# 3  00000000-0000-0000-976D-89DBD361B062  Symptoms of Depressive Disorder
# 4  00000000-0000-0000-BDF1-6960841430B0  Symptoms of Depressive Disorder
# 5  00000000-0000-0000-D6A5-01AEBD5B505A  Symptoms of Depressive Disorder
#
#     Group          State       Subgroup  Phase Time Period  \
# 1  By Age  United States  18 - 29 years    1.0           1
# 2  By Age  United States  30 - 39 years    1.0           1
# 3  By Age  United States  40 - 49 years    1.0           1
# 4  By Age  United States  50 - 59 years    1.0           1
# 5  By Age  United States  60 - 69 years    1.0           1
#
#   Time Period Start Date Time Period End Date Value Low CI High CI  \
# 1             2020-04-23           2020-05-05  32.7   30.2    35.2
# 2             2020-04-23           2020-05-05  25.7   24.1    27.3
# 3             2020-04-23           2020-05-05  24.8   23.3    26.2
# 4             2020-04-23           2020-05-05  23.2   21.5      25
# 5             2020-04-23           2020-05-05  18.4     17    19.7
#
#   Confidence Interval Quartile Range  Start year  End year  \
# 1         30.2 - 35.2              0      2020.0    2020.0
# 2         24.1 - 27.3              0      2020.0    2020.0
# 3         23.3 - 26.2              0      2020.0    2020.0
# 4         21.5 - 25.0              0      2020.0    2020.0
# 5         17.0 - 19.7              0      2020.0    2020.0
#
#    Days count of symptoms Symtoms during the same year Related to Age  \
# 1                    12.0                          Yes            Yes
# 2                    12.0                          Yes            Yes
# 3                    12.0                          Yes            Yes
# 4                    12.0                          Yes            Yes
# 5                    12.0                          Yes            Yes
#
#   Start Age End Age
# 1        18      29
# 2        30      39
# 3        40      49
# 4        50      59
# 5        60      69

# %% [markdown]
# ## **Exporting full data set into csv**

# %%
indicators.to_csv("C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicators.csv", ',')

# %%
client = MongoClient("localhost", 27017)
database = client["anxiety"]
database

filepath = "C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicators.csv"

def importcsv_tomongo(filepath, database_name, collection_name, host="localhost", port=27017):
    client = MongoClient("localhost", 27017)
    database_name = client["anxiety"]
    collection_name = database["indicators"]

    try:
        data = pd.read_csv(filepath)
        print(f"CSV File {filepath} has been successfully loaded.")
    except Exception as e:
        print(f"Error reading CSV file {e}")
        return 0
    datadict = data.to_dict(orient="records")

    try:
        result = collection_name.insert_many(datadict)
        print(f"Inserted {len(result.inserted_ids)} documents into the '{collection_name}' collection.")
        return len(result.inserted_ids)
    except Exception as e:
        print(f"Error inserting data into MongoDB: {e}")
        return 0

# %%
if __name__ == "__main__":
    filepath = filepath
    database_name = "anxiety"
    collection_name = "indicators"

    inserted_count = importcsv_tomongo(filepath, database_name, collection_name)
    print(f"Total documents inserted: {inserted_count}")
# Out:
# CSV File C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicators.csv has been successfully loaded.
# Inserted 16794 documents into the 'Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'anxiety'), 'indicators')' collection.
# Total documents inserted: 16794

# %% [markdown]
# ## **Exporting only age related data into csv file**

# %%
by_age.to_csv("C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicators_byage.csv", ',')

# %%
client = MongoClient("localhost", 27017)
database = client["anxiety"]
database

filepath = "C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicators_byage.csv"

def importcsv_tomongo(filepath, database_name, collection_name, host="localhost", port=27017):
    client = MongoClient("localhost", 27017)
    database_name = client["anxiety"]
    collection_name = database["indicators_byage"]

    try:
        data = pd.read_csv(filepath)
        print(f"CSV File {filepath} has been successfully loaded.")
    except Exception as e:
        print(f"Error reading CSV file {e}")
        return 0
    datadict = data.to_dict(orient="records")

    try:
        result = collection_name.insert_many(datadict)
        print(f"Inserted {len(result.inserted_ids)} documents into the '{collection_name}' collection.")
        return len(result.inserted_ids)
    except Exception as e:
        print(f"Error inserting data into MongoDB: {e}")
        return 0

# %%
if __name__ == "__main__":
    filepath = filepath
    database_name = "anxiety"
    collection_name = "indicators_byage"

    inserted_count = importcsv_tomongo(filepath, database_name, collection_name)
    print(f"Total documents inserted: {inserted_count}")
# Out:
# CSV File C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicators_byage.csv has been successfully loaded.
# Inserted 1722 documents into the 'Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'anxiety'), 'indicators_byage')' collection.
# Total documents inserted: 1722

# %% [markdown]
# ## **Extracting the categories of the data set**

# %%
categories = pd.read_csv("C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/indicators.csv")

# %%
categories.nunique().sort_values()
# Out:
# Related to Age                      2
# Symtoms during the same year        2
# Indicator                           3
# End year                            5
# Start year                          5
# End Age                             7
# Start Age                           7
# Group                               9
# Days count of symptoms             10
# Phase                              16
# State                              52
# Time Period                        72
# Subgroup                           78
# Time Period Start Date             82
# Time Period End Date               82
# Low CI                            574
# Value                             606
# High CI                           642
# Quartile Range                    842
# Confidence Interval             12516
# id                              16794
# Unnamed: 0                      16794
# dtype: int64

# %%
categories = categories[["Group", "Subgroup"]]
categories.head()
# Out:
#                Group       Subgroup
# 0  National Estimate  United States
# 1             By Age  18 - 29 years
# 2             By Age  30 - 39 years
# 3             By Age  40 - 49 years
# 4             By Age  50 - 59 years

# %%
categories["Group"].value_counts()
# Out:
# By State                      11016
# By Age                         1722
# By Race/Hispanic ethnicity     1230
# By Education                    984
# By Sex                          492
# By Gender identity              396
# By Sexual orientation           396
# By Disability status            312
# National Estimate               246
# Name: Group, dtype: int64

# %%
categories["Subgroup"].value_counts()
# Out:
# United States                      246
# Hispanic or Latino                 246
# 18 - 29 years                      246
# Bachelor's degree or higher        246
# Some college/Associate's degree    246
#                                   ...
# Cis-gender female                  132
# Transgender                        132
# Gay or lesbian                     132
# Straight                           132
# Bisexual                           132
# Name: Subgroup, Length: 78, dtype: int64

# %% [markdown]
# ### **Tables by group**

# %%
grouped_tables = {
    group: pd.DataFrame({"Subgroup": group_data["Subgroup"].unique()})
    for group, group_data in categories.groupby("Group")
}

for group, table in grouped_tables.items():
    print(f"Group {group} Table:")
    print(table)
    print()
# Out:
# Group By Age Table:
#              Subgroup
# 0       18 - 29 years
# 1       30 - 39 years
# 2       40 - 49 years
# 3       50 - 59 years
# 4       60 - 69 years
# 5       70 - 79 years
# 6  80 years and above
#
# Group By Disability status Table:
#              Subgroup
# 0     With disability
# 1  Without disability
#
# Group By Education Table:
#                           Subgroup
# 0  Less than a high school diploma
# 1       High school diploma or GED
# 2  Some college/Associate's degree
# 3      Bachelor's degree or higher
#
# Group By Gender identity Table:
#             Subgroup
# 0    Cis-gender male
# 1  Cis-gender female
# 2        Transgender
#
# Group By Race/Hispanic ethnicity Table:
#                                        Subgroup
# 0                            Hispanic or Latino
# 1               Non-Hispanic White, single race
# 2               Non-Hispanic Black, single race
# 3               Non-Hispanic Asian, single race
# 4  Non-Hispanic, other races and multiple races
#
# Group By Sex Table:
#   Subgroup
# 0     Male
# 1   Female
#
# Group By Sexual orientation Table:
#          Subgroup
# 0  Gay or lesbian
# 1        Straight
# 2        Bisexual
#
# Group By State Table:
#                 Subgroup
# 0                Alabama
# 1                 Alaska
# 2                Arizona
# 3               Arkansas
# 4             California
# 5               Colorado
# 6            Connecticut
# 7               Delaware
# 8   District of Columbia
# 9                Florida
# 10               Georgia
# 11                Hawaii
# 12                 Idaho
# 13              Illinois
# 14               Indiana
# 15                  Iowa
# 16                Kansas
# 17              Kentucky
# 18             Louisiana
# 19                 Maine
# 20              Maryland
# 21         Massachusetts
# 22              Michigan
# 23             Minnesota
# 24           Mississippi
# 25              Missouri
# 26               Montana
# 27              Nebraska
# 28                Nevada
# 29         New Hampshire
# 30            New Jersey
# 31            New Mexico
# 32              New York
# 33        North Carolina
# 34          North Dakota
# 35                  Ohio
# 36              Oklahoma
# 37                Oregon
# 38          Pennsylvania
# 39          Rhode Island
# 40        South Carolina
# 41          South Dakota
# 42             Tennessee
# 43                 Texas
# 44                  Utah
# 45               Vermont
# 46              Virginia
# 47            Washington
# 48         West Virginia
# 49             Wisconsin
# 50               Wyoming
#
# Group National Estimate Table:
#         Subgroup
# 0  United States

# %% [markdown]
# ### **By Age**

# %%
table_byage = categories[categories["Group"] == "By Age"]
table_byage = table_byage.drop_duplicates()
table_byage


table_byage.to_csv("C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/categories_byage.csv", ',')

# %% [markdown]
# ### **By State**

# %%
table_bystate = categories[categories["Group"] == "By State"]
table_bystate = table_bystate.drop_duplicates()
table_bystate

table_bystate.to_csv("C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/categories_bystate.csv", ',')

# %% [markdown]
# ### **Other categories**

# %%
table_others = categories[categories["Group"] != "By State"]
table_others = categories[categories["Group"] != "By Age"]
table_others = table_others.drop_duplicates()
table_others

table_others.to_csv("C:/Users/cmanu/OneDrive/Escritorio/NCIDA/ANALYTICS/PROJECT/categories_byothers.csv", ',')
